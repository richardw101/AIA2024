# %% [markdown]
# # Workshop 6 - Wherry
#
# This notebook will cover the following topics:
#
# 1. Graphs
# 2. Trees
# 4. Binary Trees
# 5. Traversals
# 6. Searching
#     - BFS
#     - DFS

# %%
'''
Graph Creation
NetworkX graph objects can be created in one of three ways:

Graph generators—standard algorithms to create network topologies.

Importing data from preexisting (usually file) sources.

Adding edges and nodes explicitly.

Explicit addition and removal of nodes/edges is the easiest to describe. Each graph object supplies methods to manipulate the graph. For example,
'''

import networkx as nx
G = nx.Graph()
G.add_edge(1, 2)  # default edge data=1
G.add_edge(2, 3, weight=0.9)  # specify edge data
Edge attributes can be anything:

import math
G.add_edge('y', 'x', function=math.cos)
G.add_node(math.cos)  # any hashable can be a node

# You can add many edges at one time:

elist = [(1, 2), (2, 3), (1, 4), (4, 2)]
G.add_edges_from(elist)
elist = [('a', 'b', 5.0), ('b', 'c', 3.0), ('a', 'c', 1.0), ('c', 'd', 7.3)]
G.add_weighted_edges_from(elist)

# %% [markdown]
# ## 6.1 GRAPHS AND TREES (NETWORKX) (Follow)
#
# **Learning Objectives:**
#
# 1. Understand the structure of graphs.
# 2. Understand how to create graphs.
# 3. Understand the network X library in python.
# 4. Learn to use network X

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\richa\.conda\envs\aia\lib\site-packages (3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
Add comments for you own reference

Code Reference: 
https://networkx.org/documentation/stable/reference/introduction.html
"""
import numpy
numpy.random.seed(42)

import networkx as nx

G = nx.Graph()
G.add_node(1)
G.add_node(2)
G.add_nodes_from([3, 4, 5])

G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(3, 4)
G.add_edge(3, 5)
G.add_edge(2, 5)
G.add_edge(1, 5)

nx.draw(G, with_labels = True)

print("The number of nodes in the graph = ", G.number_of_nodes())
print("The number of edges in the graph = ", G.number_of_edges())
# Out:
# The number of nodes in the graph =  5
# The number of edges in the graph =  6

# %%
"""
Add comments for you own reference

Code Reference: 
https://networkx.org/documentation/stable/reference/introduction.html
"""

import networkx as nx
numpy.random.seed(42)

G = nx.Graph()
elist = [('a', 'b'), ('a', 'c'),('a', 'x'),('b', 'd'), ('b', 'g'),('c', 'e'), ('c', 'f')]
G.add_edges_from(elist)

nx.draw(G, with_labels = True)

print("The number of nodes in the tree = ", G.number_of_nodes())
print("The number of edges in the tree = ", G.number_of_edges())
print("The Root of tree = a")
# Out:
# The number of nodes in the tree =  8
# The number of edges in the tree =  7
# The Root of tree = a

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. How the graph is defined? **The graph is defined via the specification of elist in the code above.***
# 2. What is the difference between adding nodes and edges serpeately and adding via edge list?
# ***Defining separately is clearer in my mind. The edge list is convenient but not as clear, e.g. not clear what all the vertices are. You have to study the individual pairs to come up with unique vertices.***
# 3. How does visualization of graph help? ***Enables you to view both vertices and edges very quickly.***

# %% [markdown]
# ## 6.1 GRAPHS AND TREES (NETWORKX) (Group)
#
# Write a program that will do the following:
#
# 1. Create a graph based on user input
# 2. Take number of nodes from user and ask user to enter edges (you can get creative in taking inputs)
# 3. (Optional) Get labels of each node
# 4. Use networkx to create a graph / tree as required by the user.
# 5. Display the graph

# %%
import networkx as nx
import numpy as np
np.random.seed(42)


def get_alphabet(n):
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    return [alphabet[i] for i in range(n)]

def main():
    my_nodes = int(input("How many nodes do you want?:"))
    if my_nodes > 26 or my_nodes < 1:
        print("Please enter a number between 1 and 26.")
    else:
        vrtx = get_alphabet(my_nodes)
        
    # generate vertices list a, b, c, d, ...
    print(f"Thank you. Here are the vertices I have created for you: {vrtx}")
        
    #my_edges = tuple(input("Please tell me which edges you would like in the graph:"))
    #type(my_edges)

    # now generate graph based on these inputs
    myG = nx.Graph()
    
    myG.add_nodes_from(vrtx)
    
    # Cheating a bit here
    elist = [('a', 'b'), ('a', 'c'),('b', 'd'),('c', 'e'),('a', 'e')]
    my_edges = elist
    print(my_edges)
    
    myG.add_edges_from(my_edges)
    # draw graph and output basic graph parameters
    nx.draw(myG, with_labels = True)

    print("The number of nodes in the tree = ", myG.number_of_nodes())
    print("The number of edges in the tree = ", myG.number_of_edges())
    print("The Root of tree = a")
    

if __name__ == "__main__":
    main()
# Out:
# How many nodes do you want?:5
# Thank you. Here are the vertices I have created for you: ['a', 'b', 'c', 'd', 'e']
# Please tell me which edges you would like in the graph:blah
# [('a', 'b'), ('a', 'c'), ('b', 'd'), ('c', 'e'), ('a', 'e')]
# The number of nodes in the tree =  5
# The number of edges in the tree =  5
# The Root of tree = a

# %%
# from class
import networkx as nx
import random as r

# didn’t do user input

G = nx.Graph()
n_nodes = int(6)
n_edges = int(5)
labels = {}

for i in range(n_nodes):
    label = f"label_{i}"
    G.add_node(i, label=label)
    labels[i] = label
   

for i in range(n_edges+1):
    num = r.randint(0, n_edges)
    if i != num:
        G.add_edge(i, num)
    else:
        G.add_edge(i, 2)
    
    
G.add_edge(n_nodes-1, 0)
nx.draw(G, labels=labels, with_labels=True)

# %% [markdown]
# ## 6.2 GRAPHS AND TREES (Follow)
# **Learning Objectives:**
#
# 1. Understand Graph as a class.
# 2. Learn to naviagate Graphs and trees.
# 3. Understand the defaultdict in Python.
# 4. Learn to use Graph class to perform graph operations
#
# ***See the tutorial on this which create a Graph class w/o networkx..https://www.tutorialspoint.com/python_data_structure/python_graphs.htm***

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx
 
class Graph:
    def __init__(self):
        self.graph = defaultdict(list)
 
    def addEdge(self,u,v):
        self.graph[u].append(v)
    
    def plotGraph(self):
        plot = nx.Graph()
        elist = []
        for i in self.graph:
            for j in self.graph[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)

# %%
"""
Add comments for you own reference
"""

g = Graph()
g.addEdge(1, 2)
g.addEdge(1, 3)
g.addEdge(3, 4)
g.addEdge(3, 5)
g.addEdge(2, 5)
g.addEdge(1, 5)

g.plotGraph()

# %%
"""
Add comments for you own reference
"""

t = Graph()
t.addEdge('a', 'b')
t.addEdge('a', 'c')
t.addEdge('a', 'x')
t.addEdge('b', 'd')
t.addEdge('b', 'g')
t.addEdge('c', 'e')
t.addEdge('c', 'f')

t.plotGraph()

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. How does class structure store nodes and edges? ***Seems to store it as a dictionary of dictionaries, where the top level dictionay keys are the vertices and the values a dictionary of the edges associated with that vertices.***
# 2. What is the use of this class structure? ***Easy to extract list of unique vertices. Clean way to add/insert/remove edges and vertices.***
# 3. Try plotting different graphs. ***okay***

# %% [markdown]
# ## 6.2 GRAPHS AND TREES (Group)
#
# Write a program that will do the following:
#
# 1. Use the Class Graph to create a random graph
# 2. Get number of nodes and number of edges from the user.
# 3. Randomly assign edges to the graph (e > number of nodes)
# 4. Display the resulting graph.

# %%
from collections import defaultdict
import networkx as nx
 
class Graph:
    def __init__(self):
        self.graph = defaultdict(list)
 
    def addEdge(self,u,v):
        self.graph[u].append(v)
    
    def plotGraph(self):
        plot = nx.Graph()
        elist = []
        for i in self.graph:
            for j in self.graph[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)

def main():
    t = Graph()
    
    # tell me how many vertices you want
    
    # Do this randomly
    t.addEdge('a', 'b')
    t.addEdge('a', 'c')
    t.addEdge('a', 'x')
    t.addEdge('b', 'd')
    t.addEdge('b', 'g')
    t.addEdge('c', 'e')
    t.addEdge('c', 'f')

    t.plotGraph()

if __name__ == "__main__":
    main()

# %%
# From Samir
import numpy
numpy.random.seed(42)


nodes = int(input("Enter number of Nodes : "))
edges = int(input("Enter number of Edges : "))

rng = numpy.random.default_rng(99999)


g = Graph()
for i in range(edges): 
       node1= rng.integers(low=1, high=nodes)
       node2 = rng.integers(low=1, high=nodes)
       print(node1, node2)
       g.addEdge(node1, node2)
        
g.plotGraph()

# %% [markdown]
# ## 6.3 BINARY TREES (Follow)
# **Learning Objectives:**
#
# 1. Understand binary trees.
# 2. Understand binary tree structure.
# 3. Understand the necessity for binary trees.
#
# ***See the tutorial on this....https://www.tutorialspoint.com/python_data_structure/python_binary_tree.htm***
#
# Also, what is this default dictionary in the collections library?
# https://www.geeksforgeeks.org/defaultdict-in-python/
#
# Looks like it is basically a dictionary that will throw a key error. However:
# When the list class is passed as the default_factory argument, then a
# defaultdict is created with the values that are list.
#
# Which is what we want for our Tree class below.
#
# E.g. look at the code below...

# %%
from collections import defaultdict 
  
# Defining a dict 
d = defaultdict(list) 
  
for i in range(5): 
    d[i].append(i) 
      
print("Dictionary with values as list:") 
print(d)
# Out:
# Dictionary with values as list:
# defaultdict(<class 'list'>, {0: [0], 1: [1], 2: [2], 3: [3], 4: [4]})

# %%
from collections import defaultdict
import networkx as nx

type(defaultdict(list))
# Out:
# collections.defaultdict

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx
 
class Tree:
    def __init__(self):
        # the Tree is instantiated via an empty defaultdict
        # which takes a list when we define it
        # pass
        self.tree = defaultdict(list)
    
    def __str__(self):
        s = ""
        for i in self.tree:
            s += f'\n {i} -> {self.tree[i]}'
        return s
    
    def getTree(self):
        return self.tree
 
    def addEdge(self,u,v):
        self.tree[u].append(v)
        print(f"I am appending: {v} to Tree {u}")
    
    def plotTree(self):
        plot = nx.Graph()
        elist = []
        for i in self.tree:
            for j in self.tree[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)

# %%
"""
Add comments for you own reference
"""

t = Tree()
t.addEdge('a', 'b')
t.addEdge('a', 'c')
t.addEdge('b', 'd')
t.addEdge('b', 'g')
t.addEdge('c', 'e')
t.addEdge('c', 'f')
t.addEdge('f', 'i')
t.addEdge('f', 'h')
t.addEdge('e', 'j')
t.addEdge('e', 'k')

t.plotTree()
print(t)
# Out:
# I am appending: b to Tree a
# I am appending: c to Tree a
# I am appending: d to Tree b
# I am appending: g to Tree b
# I am appending: e to Tree c
# I am appending: f to Tree c
# I am appending: i to Tree f
# I am appending: h to Tree f
# I am appending: j to Tree e
# I am appending: k to Tree e
#
#  a -> ['b', 'c']
#  b -> ['d', 'g']
#  c -> ['e', 'f']
#  f -> ['i', 'h']
#  e -> ['j', 'k']

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. What differentiates a binary tree?
# 2. What is the use of a binary tree?
# 3. How can you check if a given tree is binary or not?

# %% [markdown]
# ## 6.3 BINARY TREES (Group)
#
# Write a program that will do the following:
#
# 1. Use the tree class to generate a tree
# 2. Create a function that checks if a tree is binary
# 3. Take input from user for generating a tree
# 4. Check if user given tree is binary tree or not

# %%
# Import needed libraries
from collections import defaultdict
import networkx as nx

# Define a tree
bt = Tree()


bt.addEdge('a', 'b')
bt.addEdge('a', 'c')
bt.addEdge('b', 'd')
bt.addEdge('b', 'g')
bt.addEdge('c', 'e')
bt.addEdge('c', 'f')
bt.addEdge('f', 'i')
bt.addEdge('f', 'h')
bt.addEdge('e', 'j')
bt.addEdge('e', 'k')

#bt.addEdge('a', 'e')

bt.plotTree()
print(bt)

# Now to check that it is brinary, I need to confirm
# that each node has no more than two children
def isBT(thetree):
    # iterate through the
    treetype = True
    for i in thetree:
            if len(thetree[i]) != 2:
                treetype = False
    return treetype


isaBT = isBT(bt.getTree())
print(f"\nChecking if this is a binary tree: {isaBT}")
# Out:
# I am appending: b to Tree a
# I am appending: c to Tree a
# I am appending: d to Tree b
# I am appending: g to Tree b
# I am appending: e to Tree c
# I am appending: f to Tree c
# I am appending: i to Tree f
# I am appending: h to Tree f
# I am appending: j to Tree e
# I am appending: k to Tree e
#
#  a -> ['b', 'c']
#  b -> ['d', 'g']
#  c -> ['e', 'f']
#  f -> ['i', 'h']
#  e -> ['j', 'k']
#
# Checking if this is a binary tree: True

# %% [markdown]
# ## 6.4 TRAVERSALS (Follow)
# **Learning Objectives:**
#
# 1. Understand how to traverse a graph.
# 2. Understand the different kinds of graph traversals.
# 3. Learn algorithms for Depth First and Breadth first Traversals

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx
 
class Tree:
    def __init__(self):
        self.tree = defaultdict(list)
    
    def __str__(self):
        s = ""
        for i in self.tree:
            s += f'\n {i} -> {self.tree[i]}'
        return s
 
    def addEdge(self,u,v):
        self.tree[u].append(v)
    
    def plotTree(self):
        plot = nx.Graph()
        elist = []
        for i in self.tree:
            for j in self.tree[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)
        
    def inorder_traversal(self,root):
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            self.inorder_traversal(self.tree[root][0])
            print(root)
            if len(self.tree[root]) > 1:
                self.inorder_traversal(self.tree[root][1])
                

         
    def preorder_traversal(self,root):
        if not self.tree[root]:
            if root!=' ':
                print(root)
        else:
            print(root)
            self.preorder_traversal(self.tree[root][0])
            if len(self.tree[root]) > 1:
                self.preorder_traversal(self.tree[root][1])

# %%
"""
Add comments for you own reference
"""

t = Tree()
t.addEdge('f', 'b')
t.addEdge('f', 'g')
t.addEdge('b', 'a')
t.addEdge('b', 'd')
t.addEdge('d', 'c')
t.addEdge('d', 'e')
t.addEdge('g', ' ')
t.addEdge('g', 'i')
t.addEdge('i', 'h')

t.plotTree()
#print(t)
print("INORDER TRAVERSAL")
t.inorder_traversal('f')
print()

print("PREORDER TRAVERSAL")
t.preorder_traversal('f')
print()

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. Try to understand the difference between different traversals.
# 2. What is the pro of each kind of traversal?
# 3. How would you traverse breadth first?

# %% [markdown]
# ## 6.4 TRAVERSALS (Group)
#
# Write a program that will do the following:
#
# 1. Use the code above as reference to create a new tree class
# 2. Add function to traverse post order
# 3. Make sure to use the same tree structure
# 4. Add functionality to the program by making it traverse an N size tree.

# %% [markdown]
# ## 6.5 SEARCHING (Follow)
# **Learning Objectives:**
#
# 1. Understand how to search in a graph.
# 2. Understand the different kinds of graph searchs.
# 3. Learn algorithms for Depth First and Breadth first Searching
# 4. Understand the necessity of Graph searching.

# %%
"""
Add comments for you own reference
"""

from collections import defaultdict
import networkx as nx


class Graph:
    def __init__(self):
        self.graph = defaultdict(list)
 
    def addEdge(self,u,v):
        self.graph[u].append(v)
    
    def plotGraph(self):
        plot = nx.DiGraph()
        elist = []
        for i in self.graph:
            for j in self.graph[i]:
                elist.append((i,j))
        plot.add_edges_from(elist)
        nx.draw(plot, with_labels = True)
    
    
    def BFS(self, s, g):
        visited_queue = []
        BFS_queue = []
 
        BFS_queue.append(s)
        visited_queue.append(s)
        if s == g:
            print("Goal found!", visited_queue)
            return
            
        while BFS_queue:
            s = BFS_queue.pop(0)
 
            for i in self.graph[s]:
                if i not in visited_queue:
                    BFS_queue.append(i)
                    visited_queue.append(i)
                    if i == g:
                        print("Goal found!", visited_queue)
                        return
                    
                    
    def DFS(self, s, g):
        visited_list = []
        DFS_stack = []
 
        DFS_stack.append(s)
        visited_list.append(s)
        if s == g:
            print("Goal found!", visited_list)
            return
    
        while DFS_stack:
            s = DFS_stack.pop(-1)

            for i in self.graph[s]:
                if i not in visited_list:
                    DFS_stack.append(i)
                    visited_list.append(i)
                    if i == g:
                        print("Goal found!", visited_list)
                        return

# %%
"""
Add comments for you own reference
"""

g = Graph()
g.addEdge(0, 1)
g.addEdge(0, 2)
g.addEdge(1, 2)
g.addEdge(2, 0)
g.addEdge(2, 3)
g.addEdge(3, 4)

start_node = 2
goal_node = 4

print (f"Breadth First Tree Search (starting from node {start_node})")
g.BFS(start_node, goal_node)

g.plotGraph()

# %%
"""
Add comments for you own reference
"""

g = Graph()
g.addEdge(0, 1)
g.addEdge(0, 2)
g.addEdge(1, 2)
g.addEdge(2, 0)
g.addEdge(2, 3)
g.addEdge(3, 4)
 
start_node = 2
goal_node = 4

print(f"Following is DFS from (starting from node {start_node})")
g.DFS(start_node, goal_node)

g.plotGraph()

# %% [markdown]
# **Evaluation:**
#
# After running this program, think about and answer these questions:
#
# 1. Try to understand the difference between different Searches.
# 2. What is the use case of each type of search?
# 3. How are BFS and DFS different from regular searching algothms?

# %% [markdown]
# ## 6.5 SEARCHING (Group)
#
# Write a program that will do the following:
#
# 1. Implement depth first search and breadth first search.
# 2. Implement a class Node.
# 3. Node class should have attributes value, and parent.
# 4. Graph class should **not** inherit the node class.
# 5. Create a graph object and use the add edge function to create a graph of nodes.
# 6. Create at least 5 or 6 nodes.
# 7. Perform DFS and print the results of DFS and BFS.
# 8. As an added challenge, create a function to keep track of the parents of each node.
# 9. If you create the function, try printing these parents.
